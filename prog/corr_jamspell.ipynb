# %%
# !sudo apt-get install swig3.0
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   swig3.0-examples swig3.0-doc
# The following NEW packages will be installed:
#   swig3.0
# 0 upgraded, 1 newly installed, 0 to remove and 32 not upgraded.
# Need to get 1,109 kB of archives.
# After this operation, 5,555 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig3.0 amd64 3.0.12-2.2ubuntu1 [1,109 kB]
# Fetched 1,109 kB in 1s (1,553 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# ...

# %%
# !sudo pip install jamspell
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.3/174.3 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for jamspell: filename=jamspell-0.0.12-cp310-cp310-linux_x86_64.whl size=1782251 sha256=4647922a554443d4e578834e8b6a49f5f2da869d6493f032cfa1d4fc5aad9d95
#   Stored in directory: /root/.cache/pip/wheels/95/af/d3/fb57122fda2851ad5972ce80640001c568dcffdf16bc9ddb17
# Successfully built jamspell
# ...

# %%
# !wget https://github.com/bakwc/JamSpell-models/raw/master/fr.tar.gz
# Out:
# --2024-02-06 16:13:54--  https://github.com/bakwc/JamSpell-models/raw/master/fr.tar.gz
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/bakwc/JamSpell-models/master/fr.tar.gz [following]
# --2024-02-06 16:13:54--  https://raw.githubusercontent.com/bakwc/JamSpell-models/master/fr.tar.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32421326 (31M) [application/octet-stream]
# Saving to: ‘fr.tar.gz’
#
# fr.tar.gz           100%[===================>]  30.92M  --.-KB/s    in 0.1s
#
# 2024-02-06 16:13:56 (221 MB/s) - ‘fr.tar.gz’ saved [32421326/32421326]

# %%
# !tar -xvf fr.tar.gz
# Out:
# fr.bin

# %%
## Test
import jamspell

corrector = jamspell.TSpellCorrector()
corrector.LoadLangModel('ELTeCfr.bin')

corrector.FixFragment('Bnojour, cecci est un tutorie')
# u'I am the best spell checker!'
# Out:
# 'Bonjour, cecci est un tutorie'

# %%
from posixpath import split
import glob
from google.colab import drive
drive.mount('/content/drive')
import jamspell

def ouverture_fichier(filename):
    print("lecture fichier",filename)
    f = open(filename, "r")
    textlu = f.read()
    f.close()
    print("Ecriture OK")
    return textlu

def ecriture_fichier(filename,Texte):
    print("Ecriture du fichier",filename)
    w = open(filename, "w")
    w.write(Texte)
        #w.write('\n')
    w.close()
    print(filename,"Ecriture OK")

def nom_fichier(chemin):
  chemin = chemin.split(".")[0]
  return(chemin)


jsp = jamspell.TSpellCorrector()   # initialiser le correcteur
assert jsp.LoadLangModel('fr.bin') # spécifier le modèle de langue
path_corpora="/content/drive/MyDrive/Colab Notebooks/TGB/*/*/*"

for path in glob.glob(path_corpora):
  print(path)
  #texte = ouverture_fichier(path)
  #print(texte)
  OCR_txt=path.split("_")
  #print(OCR_txt)
  #if OCR_txt[-1]!="PP.txt":
  if OCR_txt[-1]!="REF.txt":
    texte = ouverture_fichier(path)
    texte_corr=jsp.FixFragment(texte)
    name_file= nom_fichier(path)
    print(name_file)
    ecriture_fichier("%s_jamspell-pretrain-fr.txt"%name_file,texte_corr)

#print(texte_corr)
    #print(OCR_txt)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/TGB/PONTMARTIN/PONTMARTIN_REF/PONTMARTIN_Souvenirs-dun-vieux-melomane_REF.txt
# /content/drive/MyDrive/Colab Notebooks/TGB/PONTMARTIN/PONTMARTIN_TesseractFra-bin/PONTMARTIN_Souvenirs-dun-vieux-melomane_TesseractFra-bin.txt
# lecture fichier /content/drive/MyDrive/Colab Notebooks/TGB/PONTMARTIN/PONTMARTIN_TesseractFra-bin/PONTMARTIN_Souvenirs-dun-vieux-melomane_TesseractFra-bin.txt
# Ecriture OK
# /content/drive/MyDrive/Colab Notebooks/TGB/PONTMARTIN/PONTMARTIN_TesseractFra-bin/PONTMARTIN_Souvenirs-dun-vieux-melomane_TesseractFra-bin
# Ecriture du fichier /content/drive/MyDrive/Colab Notebooks/TGB/PONTMARTIN/PONTMARTIN_TesseractFra-bin/PONTMARTIN_Souvenirs-dun-vieux-melomane_TesseractFra-bin_jamspell-pretrain-fr.txt
# /content/drive/MyDrive/Colab Notebooks/TGB/PONTMARTIN/PONTMARTIN_TesseractFra-bin/PONTMARTIN_Souvenirs-dun-vieux-melomane_TesseractFra-bin_jamspell-pretrain-fr.txt Ecriture OK
# ...
